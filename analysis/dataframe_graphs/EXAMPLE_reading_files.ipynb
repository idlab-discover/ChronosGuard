# %%
# !pip install pyarrow

# %%
import numpy as np
import pandas as pd

# %%
BASE_DIR = "../../../CNSM_DATA/v2"

# %% [markdown]
# # Read Merged Details

# %%
df_merged = pd.read_parquet(BASE_DIR + "/cluster/1pod/cluster_1pod_ks_initial/merged/detail.parquet")
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210672 entries, 0 to 210671
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   request_type                 210672 non-null  category
#  1   name                         210672 non-null  category
#  2   response_time_ms             210672 non-null  int64
#  3   response_length              210672 non-null  int64
#  4   event_timestamp              210672 non-null  datetime64[ns]
#  5   finished_timestamp           210671 non-null  datetime64[ns]
#  6   num_of_users                 210672 non-null  int64
#  7   timestamp_start              210671 non-null  datetime64[ns]
#  8   timestamp_end                210671 non-null  datetime64[ns]
#  9   processing_timestamp_start   0 non-null       datetime64[ns]
#  10  processing_timestamp_end     0 non-null       datetime64[ns]
# ...

# %%
df_merged.head(1)
# Out:
#   request_type    name  response_time_ms  response_length  \
# 0         POST  Benign                65              285
#
#              event_timestamp         finished_timestamp  num_of_users  \
# 0 2023-05-15 12:07:02.177743 2023-05-15 12:07:02.244895             1
#
#              timestamp_start              timestamp_end  \
# 0 2023-05-15 12:08:41.041600 2023-05-15 12:08:41.100079
#
#   processing_timestamp_start  ... multi_class_timestamp_end  \
# 0                        NaT  ...                       NaT
#
#   zero_day_timestamp_start zero_day_timestamp_end anomaly_score  \
# 0                      NaT                    NaT       0.00012
#
#   binary_prediction multi_class_confidence multi_class_prediction  \
# 0            Attack               0.824742                 Benign
#
#              total_delay flow_type  num_repetition
# 0 0 days 00:00:00.067152    Benign               6
#
# [1 rows x 24 columns]

# %% [markdown]
# # Read Detail Statistics

# %%
df_stat = pd.read_parquet('v2/detail_stat.parquet')
# df_stat = pd.read_csv('v2/detail_stat.csv')
# df_stat_sorting = pd.read_parquet('v2/detail_stat_sorting.parquet')
# df_stat_sorting = pd.read_csv('v2/detail_stat_sorting.csv')
df_stat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36630 entries, 0 to 36629
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   topology                36630 non-null  category
#  1   deployment              36630 non-null  category
#  2   sorting                 36630 non-null  category
#  3   scenario                36630 non-null  category
#  4   repetition              36630 non-null  category
#  5   flow_type               36630 non-null  category
#  6   num_users               36630 non-null  int64
#  7   throughput              36630 non-null  float64
#  8   response_time_ms_count  36630 non-null  float64
#  9   response_time_ms_mean   34378 non-null  float64
#  10  response_time_ms_std    34362 non-null  float64
#  11  response_time_ms_min    34378 non-null  float64
#  12  response_time_ms_25%    34378 non-null  float64
#  13  response_time_ms_50%    34378 non-null  float64
# ...

# %%
df_stat.head(3)
# Out:
#   topology deployment sorting    scenario repetition flow_type  num_users  \
# 0  cluster       1pod   ks_ks  scale-down          1    Benign          1
# 1  cluster       1pod   ks_ks  scale-down          1    Attack          1
# 2  cluster       1pod   ks_ks  scale-down          1  Zero-Day          1
#
#    throughput  response_time_ms_count  response_time_ms_mean  ...  \
# 0   17.533333                   526.0              53.579848  ...
# 1    0.000000                     0.0                    NaN  ...
# 2    0.000000                     0.0                    NaN  ...
#
#    response_time_ms_25%  response_time_ms_50%  response_time_ms_60%  \
# 0                  26.0                  56.0                  64.0
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
#
#    response_time_ms_70%  response_time_ms_75%  response_time_ms_80%  \
# ...

# %%
df_resources = pd.read_parquet('v2/resources_stat.parquet')
df_resources.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49764 entries, 0 to 49763
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   topology                    49764 non-null  category
#  1   deployment                  49764 non-null  category
#  2   sorting                     49764 non-null  category
#  3   scenario                    49764 non-null  category
#  4   repetition                  49764 non-null  category
#  5   num_users                   49764 non-null  int64
#  6   container                   49764 non-null  category
#  7   cpu_unit                    49764 non-null  object
#  8   cpu_avg                     37057 non-null  float64
#  9   cpu_min                     37057 non-null  float64
#  10  cpu_max                     37057 non-null  float64
#  11  cpu_stddev                  37057 non-null  float64
#  12  cpu_count                   49764 non-null  int64
# ...

# %% [markdown]
# # Read Aggregated Detail Statistics

# %%
df_agg = pd.read_parquet('v2/detail_agg_stat.parquet')
# df_agg = pd.read_csv('v2/detail_agg_stat.csv', index_col=[0,1,2,3,4,5])
# df_agg_sorting = pd.read_parquet('v2/detail_agg_stat_sorting.parquet')
# df_agg_sorting = pd.read_csv('v2/detail_agg_stat_sorting.csv', index_col=[0,1,2,3,4,5])
df_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4158 entries, ('cluster', '1pod', 'ks_ks', 'initial', 1, 'Attack') to ('edge-fog-cloud', '4pod', 'qos_qos', 'scale-up', 100, 'Zero-Day')
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   throughput_mean              4158 non-null   float64
#  1   throughput_std               4158 non-null   float64
#  2   response_time_ms_count_mean  4158 non-null   float64
#  3   response_time_ms_count_std   4158 non-null   float64
#  4   response_time_ms_mean_mean   3906 non-null   float64
#  5   response_time_ms_mean_std    3906 non-null   float64
#  6   response_time_ms_min_mean    3906 non-null   float64
#  7   response_time_ms_min_std     3906 non-null   float64
#  8   response_time_ms_max_mean    3906 non-null   float64
#  9   response_time_ms_max_std     3906 non-null   float64
# ...

# %%
df_agg.head(3)
# Out:
#                                                           throughput_mean  \
# topology deployment sorting scenario num_users flow_type
# cluster  1pod       ks_ks   initial  1         Attack            0.000000
#                                                Benign           17.456667
#                                                Zero-Day          0.000000
#
#                                                           throughput_std  \
# topology deployment sorting scenario num_users flow_type
# cluster  1pod       ks_ks   initial  1         Attack           0.000000
#                                                Benign           0.229895
#                                                Zero-Day         0.000000
#
#                                                           response_time_ms_count_mean  \
# topology deployment sorting scenario num_users flow_type
# cluster  1pod       ks_ks   initial  1         Attack                             0.0
# ...

# %%
df_agg.loc['cluster', '3pod', 'ks_ks', 'scale-up', 100, :]
# Out:
#            throughput_mean  throughput_std  response_time_ms_count_mean  \
# flow_type
# Attack               19.71        0.920956                        591.3
# Benign              151.77        3.621181                       4553.1
# Zero-Day              2.13        0.329403                         63.9
#
#            response_time_ms_count_std  response_time_ms_mean_mean  \
# flow_type
# Attack                      27.628689                  910.649354
# Benign                     108.635425                  540.947347
# Zero-Day                     9.882083                 1284.106947
#
#            response_time_ms_mean_std  response_time_ms_min_mean  \
# flow_type
# Attack                     49.591244                       22.2
# Benign                     15.336302                       21.2
# Zero-Day                  157.638858                      145.0
#
#            response_time_ms_min_std  response_time_ms_max_mean  \
# flow_type
# ...

# %%
df_resource_agg = pd.read_parquet('v2/resources_agg_stat.parquet')
df_resource_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 5676 entries, ('cluster', '1pod', 'ks_ks', 'initial', 1, 'allinoneapi') to ('edge-fog-cloud', '4pod', 'qos_qos', 'scale-up', 100, 'zerodayapi')
# Data columns (total 40 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   cpu_count_mean                   5676 non-null   float64
#  1   cpu_count_std                    5676 non-null   float64
#  2   cpu_avg_mean                     4290 non-null   float64
#  3   cpu_avg_std                      4290 non-null   float64
#  4   cpu_min_mean                     4290 non-null   float64
#  5   cpu_min_std                      4290 non-null   float64
#  6   cpu_max_mean                     4290 non-null   float64
#  7   cpu_max_std                      4290 non-null   float64
#  8   cpu_stddev_mean                  4290 non-null   float64
#  9   cpu_stddev_std                   4290 non-null   float64
# ...
